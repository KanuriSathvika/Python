# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_excel("C:/Users/sathvika/Downloads/info.xlsx")

# %%
df=pd.DataFrame(d)

# %%
df.head()
# Out:
#    usn name  marks
# 0    1    a   98.0
# 1    2    b    NaN
# 2    3    c   78.0
# 3    4    d    NaN
# 4    5    e   90.0

# %%
df.isnull().sum()
# Out:
# usn      0
# name     0
# marks    2
# dtype: int64

# %%
df.dropna()
# Out:
#    usn name  marks
# 0    1    a   98.0
# 2    3    c   78.0
# 4    5    e   90.0
# 5    6    f   75.0
# 6    7    g   87.0
# 7    8    h   76.0
# 8    9    i   87.0
# 9   10    j   43.0

# %%
df.head()
# Out:
#    usn name  marks
# 0    1    a   98.0
# 1    2    b    NaN
# 2    3    c   78.0
# 3    4    d    NaN
# 4    5    e   90.0

# %%
df.dropna(axis=1)
# Out:
#    usn name
# 0    1    a
# 1    2    b
# 2    3    c
# 3    4    d
# 4    5    e
# 5    6    f
# 6    7    g
# 7    8    h
# 8    9    i
# 9   10    j

# %%
df.dropna(axis=0)
# Out:
#    usn name  marks
# 0    1    a   98.0
# 2    3    c   78.0
# 4    5    e   90.0
# 5    6    f   75.0
# 6    7    g   87.0
# 7    8    h   76.0
# 8    9    i   87.0
# 9   10    j   43.0

# %%
df.dropna(thresh=3)
#thresh:in dataframe aleast thresh value non null values want to there or else it drop tha values
# Out:
#    usn name  marks
# 0    1    a   98.0
# 2    3    c   78.0
# 4    5    e   90.0
# 5    6    f   75.0
# 6    7    g   87.0
# 7    8    h   76.0
# 8    9    i   87.0
# 9   10    j   43.0

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [usn, name, marks]
# Index: []

# %%
df.fillna(100)
# Out:
#    usn name  marks
# 0    1    a   98.0
# 1    2    b  100.0
# 2    3    c   78.0
# 3    4    d  100.0
# 4    5    e   90.0
# 5    6    f   75.0
# 6    7    g   87.0
# 7    8    h   76.0
# 8    9    i   87.0
# 9   10    j   43.0

# %%
m=df['marks'].mean()
m
# Out:
# 79.25

# %%
df.fillna(m)
# Out:
#    usn name  marks
# 0    1    a  98.00
# 1    2    b  79.25
# 2    3    c  78.00
# 3    4    d  79.25
# 4    5    e  90.00
# 5    6    f  75.00
# 6    7    g  87.00
# 7    8    h  76.00
# 8    9    i  87.00
# 9   10    j  43.00

# %%
mod=df['marks'].mode()
mod
# Out:
# 0    87.0
# dtype: float64

# %%
df.fillna(87.5)
# Out:
#    usn name  marks
# 0    1    a   98.0
# 1    2    b   87.5
# 2    3    c   78.0
# 3    4    d   87.5
# 4    5    e   90.0
# 5    6    f   75.0
# 6    7    g   87.0
# 7    8    h   76.0
# 8    9    i   87.0
# 9   10    j   43.0
